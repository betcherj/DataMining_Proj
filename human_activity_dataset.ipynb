# %%
import pandas as pd
from sklearn import svm
from sklearn.model_selection import cross_val_score

# %%
feature_names_df = pd.read_csv("features.txt",header= None,delim_whitespace=True)
feature_names = [featurer for featurer in feature_names_df[1]]
feature_names
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
# ...

# %%
df_train_y =  pd.read_csv("train/y_train.txt",names=["label"],header = None, delim_whitespace=True)
df_train_y
# Out:
#       label
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# 5         5
# 6         5
# 7         5
# 8         5
# 9         5
# 10        5
# 11        5
# 12        5
# 13        5
# 14        5
# 15        5
# 16        5
# 17        5
# 18        5
# 19        5
# 20        5
# 21        5
# 22        5
# 23        5
# 24        5
# 25        5
# 26        5
# 27        4
# 28        4
# 29        4
# ...     ...
# 7322      2
# 7323      2
# 7324      2
# 7325      2
# 7326      2
# 7327      2
# 7328      2
# 7329      2
# 7330      2
# 7331      2
# 7332      2
# 7333      2
# 7334      2
# 7335      2
# 7336      2
# 7337      2
# 7338      2
# 7339      2
# 7340      2
# 7341      2
# 7342      2
# 7343      2
# 7344      2
# 7345      2
# 7346      2
# 7347      2
# 7348      2
# 7349      2
# 7350      2
# 7351      2
#
# [7352 rows x 1 columns]

# %%
df_train_x = pd.read_csv("train/X_train.txt",header = None, delim_whitespace=True,names=feature_names)
df_train_x
# Out:
# C:\Users\juanm\AppData\Roaming\Python\Python27\site-packages\pandas\io\parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# 5              0.277199          -0.010098          -0.105137
# 6              0.279454          -0.019641          -0.110022
# 7              0.277432          -0.030488          -0.125360
# 8              0.277293          -0.021751          -0.120751
# 9              0.280586          -0.009960          -0.106065
# 10             0.276880          -0.012722          -0.103438
# ...

# %%
df_train = df_train_x.join(df_train_y,how="outer")
df_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# 5              0.277199          -0.010098          -0.105137
# 6              0.279454          -0.019641          -0.110022
# 7              0.277432          -0.030488          -0.125360
# 8              0.277293          -0.021751          -0.120751
# 9              0.280586          -0.009960          -0.106065
# 10             0.276880          -0.012722          -0.103438
# 11             0.276228          -0.021441          -0.108202
# 12             0.278457          -0.020415          -0.112732
# 13             0.277175          -0.014713          -0.106756
# ...

# %%
df_train = df_train_x.join(df_train_y,how="outer")
df_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# 5              0.277199          -0.010098          -0.105137
# 6              0.279454          -0.019641          -0.110022
# 7              0.277432          -0.030488          -0.125360
# 8              0.277293          -0.021751          -0.120751
# 9              0.280586          -0.009960          -0.106065
# 10             0.276880          -0.012722          -0.103438
# 11             0.276228          -0.021441          -0.108202
# 12             0.278457          -0.020415          -0.112732
# 13             0.277175          -0.014713          -0.106756
# ...

# %%
df_test_x = pd.read_csv("test/X_test.txt",header = None, delim_whitespace=True,names=feature_names)
df_test_y = pd.read_csv("test/y_test.txt",header = None,names=["label"])
df_test = df_test_x.join(df_test_y,how="outer")

# %%
df = df_test.append(df_train,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e76ae5d66bf1> in <module>()
#       1 df = df_test.append(df_train,ignore_index=True)
# ----> 2 scores = cross_val_score(clf, iris.data, iris.target, cv=5)
#
# NameError: name 'cross_val_score' is not defined

# %%
df.to_csv("human_activity.csv")

# %%
new_df = pd.read_csv("human_activity.csv")

# %%
new_df
# Out:
#        Unnamed: 0  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0               0           0.257178          -0.023285          -0.014654
# 1               1           0.286027          -0.013163          -0.119083
# 2               2           0.275485          -0.026050          -0.118152
# 3               3           0.270298          -0.032614          -0.117520
# 4               4           0.274833          -0.027848          -0.129527
# 5               5           0.279220          -0.018620          -0.113902
# 6               6           0.279746          -0.018271          -0.104000
# 7               7           0.274601          -0.025035          -0.116831
# 8               8           0.272529          -0.020954          -0.114472
# 9               9           0.275746          -0.010372          -0.099776
# 10             10           0.278596          -0.015232          -0.098908
# ...

# %%
clf = svm.SVC(kernel='linear', C=1)
scores = cross_val_score(clf, , df['label'], cv=5)

# %%
scores.mean()
# Out:
# 0.9997087847424865

# %%
# label_to_activity = {1:"WALKING",2:"WALKING_UPSTAIRS",3:"WALKING_DOWNSTAIRS",4:"SITTING",5:"STANDING",6:"LAYING"}
# df['label'] = df['label'].map(label_to_activity)
# df

# %%
# df.to_csv("human_activity",index=False)
